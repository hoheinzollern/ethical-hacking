# %%
import pandas
import os
s = pandas.DataFrame({'value':[ (int)(x*1.235)  %105 for x in os.urandom(1000000)]})
s['value'].value_counts().sort_index().plot(figsize=(20,5),kind='bar')
# Out:
# <AxesSubplot:>

# %%
import pandas
import os
values = []
while(len(values)<=1000000):
    x = int.from_bytes(os.urandom(1), byteorder='little')
    if x < 107:
        values.append(x)
s = pandas.DataFrame({'value':values})
s['value'].value_counts().sort_index().plot(figsize=(20,5),kind='bar')
# Out:
# <AxesSubplot:>
